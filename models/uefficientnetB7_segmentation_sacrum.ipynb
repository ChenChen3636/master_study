# %% [markdown]
# ### Reqirements
# - keras >= 2.2.0 or tensorflow >= 1.13
# - segmenation-models==1.0.*
# - albumentations==0.3.0

# %%
# Install required libs

### please update Albumentations to version>=0.3.0 for `Lambda` transform support
# !pip install -U albumentations>=0.3.0 --user 
# !pip install -U --pre segmentation-models --user
# Out:
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\User\AppData\Local\Programs\Python\Python38\lib\site-packages\pip\_vendor\urllib3\response.py", line 438, in _error_catcher
#     yield
#   File "C:\Users\User\AppData\Local\Programs\Python\Python38\lib\site-packages\pip\_vendor\urllib3\response.py", line 561, in read
#     data = self._fp_read(amt) if not fp_closed else b""
#   File "C:\Users\User\AppData\Local\Programs\Python\Python38\lib\site-packages\pip\_vendor\urllib3\response.py", line 527, in _fp_read
#     return self._fp.read(amt) if amt is not None else self._fp.read()
#   File "C:\Users\User\AppData\Local\Programs\Python\Python38\lib\site-packages\pip\_vendor\cachecontrol\filewrapper.py", line 98, in read
#     data: bytes = self.__fp.read(amt)
#   File "C:\Users\User\AppData\Local\Programs\Python\Python38\lib\http\client.py", line 454, in read
#     n = self.readinto(b)
#   File "C:\Users\User\AppData\Local\Programs\Python\Python38\lib\http\client.py", line 498, in readinto
#     n = self.fp.readinto(b)
#   File "C:\Users\User\AppData\Local\Programs\Python\Python38\lib\socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\User\AppData\Local\Programs\Python\Python38\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\User\AppData\Local\Programs\Python\Python38\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\User\AppData\Local\Programs\Python\Python38\lib\site-packages\pip\_internal\cli\base_command.py", line 105, in _run_wrapper
#     status = _inner_run()
#   File "C:\Users\User\AppData\Local\Programs\Python\Python38\lib\site-packages\pip\_internal\cli\base_command.py", line 96, in _inner_run
#     return self.run(options, args)
#   File "C:\Users\User\AppData\Local\Programs\Python\Python38\lib\site-packages\pip\_internal\cli\req_command.py", line 67, in wrapper
#     return func(self, options, args)
#   File "C:\Users\User\AppData\Local\Programs\Python\Python38\lib\site-packages\pip\_internal\commands\install.py", line 379, in run
#     requirement_set = resolver.resolve(
#   File "C:\Users\User\AppData\Local\Programs\Python\Python38\lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 179, in resolve
#     self.factory.preparer.prepare_linked_requirements_more(reqs)
#   File "C:\Users\User\AppData\Local\Programs\Python\Python38\lib\site-packages\pip\_internal\operations\prepare.py", line 554, in prepare_linked_requirements_more
#     self._complete_partial_requirements(
#   File "C:\Users\User\AppData\Local\Programs\Python\Python38\lib\site-packages\pip\_internal\operations\prepare.py", line 469, in _complete_partial_requirements
#     for link, (filepath, _) in batch_download:
#   File "C:\Users\User\AppData\Local\Programs\Python\Python38\lib\site-packages\pip\_internal\network\download.py", line 184, in __call__
#     for chunk in chunks:
#   File "C:\Users\User\AppData\Local\Programs\Python\Python38\lib\site-packages\pip\_internal\network\utils.py", line 65, in response_chunks
#     for chunk in response.raw.stream(
#   File "C:\Users\User\AppData\Local\Programs\Python\Python38\lib\site-packages\pip\_vendor\urllib3\response.py", line 622, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
#   File "C:\Users\User\AppData\Local\Programs\Python\Python38\lib\site-packages\pip\_vendor\urllib3\response.py", line 587, in read
#     raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#   File "C:\Users\User\AppData\Local\Programs\Python\Python38\lib\contextlib.py", line 131, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "C:\Users\User\AppData\Local\Programs\Python\Python38\lib\site-packages\pip\_vendor\urllib3\response.py", line 443, in _error_catcher
#     raise ReadTimeoutError(self._pool, None, "Read timed out.")
# pip._vendor.urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out.
# Requirement already satisfied: segmentation-models in c:\users\user\appdata\roaming\python\python38\site-packages (1.0.1)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in c:\users\user\appdata\roaming\python\python38\site-packages (from segmentation-models) (1.0.8)
# Requirement already satisfied: image-classifiers==1.0.0 in c:\users\user\appdata\roaming\python\python38\site-packages (from segmentation-models) (1.0.0)
# Requirement already satisfied: efficientnet==1.0.0 in c:\users\user\appdata\roaming\python\python38\site-packages (from segmentation-models) (1.0.0)
# Requirement already satisfied: scikit-image in c:\users\user\appdata\roaming\python\python38\site-packages (from efficientnet==1.0.0->segmentation-models) (0.21.0)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\user\appdata\roaming\python\python38\site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.24.4)
# Requirement already satisfied: h5py in c:\users\user\appdata\local\programs\python\python38\lib\site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (3.11.0)
# Requirement already satisfied: scipy>=1.8 in c:\users\user\appdata\local\programs\python\python38\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.10.1)
# Requirement already satisfied: networkx>=2.8 in c:\users\user\appdata\roaming\python\python38\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (3.1)
# Requirement already satisfied: pillow>=9.0.1 in c:\users\user\appdata\local\programs\python\python38\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (10.3.0)
# Requirement already satisfied: imageio>=2.27 in c:\users\user\appdata\roaming\python\python38\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.34.2)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\user\appdata\roaming\python\python38\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2023.7.10)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\user\appdata\roaming\python\python38\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.4.1)
# Requirement already satisfied: packaging>=21 in c:\users\user\appdata\local\programs\python\python38\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (24.0)
# Requirement already satisfied: lazy_loader>=0.2 in c:\users\user\appdata\roaming\python\python38\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (0.4)

# %% [markdown]
# # Loading dataset

# %%
import os
import tensorflow as tf
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

import cv2
import keras
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Num GPUs Available:  1

# %%
DATA_DIR = 'C:\ellie\study\models\Sacrum'

# %%
x_train_dir = os.path.join(DATA_DIR, 'train')
y_train_dir = os.path.join(DATA_DIR, 'trainannot')

x_valid_dir = os.path.join(DATA_DIR, 'val')
y_valid_dir = os.path.join(DATA_DIR, 'valannot')

x_test_dir = os.path.join(DATA_DIR, 'test')
y_test_dir = os.path.join(DATA_DIR, 'testannot')

# %% [markdown]
# # Dataloader and utility functions

# %%
# helper function for data visualization
def visualize(**images):
    """PLot images in one row."""
    n = len(images)
    plt.figure(figsize=(16, 5))
    for i, (name, image) in enumerate(images.items()):
        plt.subplot(1, n, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.title(' '.join(name.split('_')).title())
        plt.imshow(image, cmap='gray')
    plt.show()
    
# helper function for data visualization    
def denormalize(x):
    """Scale image to range 0..1 for correct plot"""
    x_max = np.percentile(x, 98)
    x_min = np.percentile(x, 2)    
    x = (x - x_min) / (x_max - x_min)
    x = x.clip(0, 1)
    return x

# classes for data loading and preprocessing
class Dataset:
    
    CLASSES = ['background', 'bone']
    
    def __init__(
            self, 
            images_dir, 
            masks_dir, 
            classes=None, 
            augmentation=None, 
            preprocessing=None,
    ):
        self.ids = os.listdir(images_dir)
        self.images_fps = [os.path.join(images_dir, image_id) for image_id in self.ids]
        self.masks_fps = [os.path.join(masks_dir, image_id.replace('.jpg', '.npy')) for image_id in self.ids]
        
        # convert str names to class values on masks
        self.class_values = [self.CLASSES.index(cls.lower()) for cls in classes] # type: ignore
        
        self.augmentation = augmentation
        self.preprocessing = preprocessing
    
    def __getitem__(self, i):
        
        # read data
        image = cv2.imread(self.images_fps[i], cv2.IMREAD_GRAYSCALE)
        image = np.expand_dims(image, axis=-1)  # 添加通道維度
        mask = np.load(self.masks_fps[i])
        
        # Process the mask: set all non-background (non-zero) labels to 1
        mask = np.where(mask != 0, 1, 0).astype('float')  # Background = 0, Bone = 1
        
         # Extract relevant classes (background and bone)
        masks = [(mask == v) for v in self.class_values]
        mask = np.stack(masks, axis=-1).astype('float')
        
        # apply augmentations
        if self.augmentation:
            sample = self.augmentation(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
        
        # apply preprocessing
        if self.preprocessing:
            sample = self.preprocessing(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
            
        return image, mask
        
    def __len__(self):
        return len(self.ids)
    
    
class Dataloder(keras.utils.Sequence): # type: ignore
    """Load data from dataset and form batches
    
    Args:
        dataset: instance of Dataset class for image loading and preprocessing.
        batch_size: Integet number of images in batch.
        shuffle: Boolean, if `True` shuffle image indexes each epoch.
    """
    
    def __init__(self, dataset, batch_size=1, shuffle=False):
        self.dataset = dataset
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indexes = np.arange(len(dataset))
        self.on_epoch_end()

    def __getitem__(self, i):
        
        # collect batch data
        start = i * self.batch_size
        stop = (i + 1) * self.batch_size
        data = [self.dataset[j] for j in range(start, stop)]
        batch = [np.stack(samples, axis=0) for samples in zip(*data)]
        return batch
    
    def __len__(self):
        """Denotes the number of batches per epoch"""
        return len(self.indexes) // self.batch_size
    
    def on_epoch_end(self):
        """Callback function to shuffle indexes each epoch"""
        if self.shuffle:
            self.indexes = np.random.permutation(self.indexes)

# %%
# Lets look at data we have
dataset = Dataset(x_train_dir, y_train_dir, classes=['background', 'bone'])

image, mask = dataset[0] # get some sample

# 可視化影像和標註
visualize(
    image=image, 
    background=mask[..., 0].squeeze(),
    bone_mask=mask[..., 1].squeeze()
)

# %% [markdown]
# ### Augmentations

# %%
import albumentations as A # type: ignore
# Out:
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.14 (you have 1.4.11). Upgrade using: pip install --upgrade albumentations

# %%
def round_clip_0_1(x, **kwargs):
    return x.round().clip(0, 1)

# define heavy augmentations
def get_training_augmentation():
    train_transform = [

        A.HorizontalFlip(p=0.3),
        A.ShiftScaleRotate(scale_limit=0.1, rotate_limit=0.1, shift_limit=0.1, p=0.5, border_mode=0),
        A.PadIfNeeded(min_height=512, min_width=512, always_apply=True, border_mode=cv2.BORDER_CONSTANT, value=0),
        A.GaussNoise(p=0.5),  
        
        A.OneOf(
            [
                A.CLAHE(p=1),
                A.RandomBrightnessContrast(brightness_limit=2, contrast_limit=0, p=1),
                A.RandomGamma(p=1),
            ],
            p=0.9,
        ),

        A.OneOf(
            [
                A.Sharpen(p=1),
                A.Blur(blur_limit=3, p=1),
                A.MotionBlur(blur_limit=3, p=1),
            ],
            p=0.9,
        ),

        A.OneOf(
            [
                A.RandomBrightnessContrast(brightness_limit=0, contrast_limit=2, p=1),
                A.HueSaturationValue(p=1),
            ],
            p=0.9,
        ),
        A.Lambda(mask=round_clip_0_1)
    ]
    return A.Compose(train_transform)


def get_validation_augmentation():
    test_transform = [
        A.PadIfNeeded(512, 512)
    ]
    return A.Compose(test_transform) # type: ignore

def get_preprocessing(preprocessing_fn):
    
    _transform = [
        A.Lambda(image=preprocessing_fn),
    ]
    return A.Compose(_transform) # type: ignore

def custom_preprocessing(image, **kwargs):
    """Apply preprocessing for grayscale images"""
    if image.shape[-1] == 1:
        image = np.repeat(image, 3, axis=-1)  # 將灰階影像複製成3個通道
    image = image.astype(np.float32) / 255.0
    return image

# %%
# Lets look at augmented data we have
dataset = Dataset(x_train_dir, y_train_dir, classes=['background', 'bone'], augmentation=get_training_augmentation())

image, mask = dataset[12] # get some sample
visualize(
    image=image, 
    background=mask[..., 0].squeeze(),
    bone_mask=mask[..., 1].squeeze()
)
# Out:
# C:\Users\User\AppData\Roaming\Python\Python38\site-packages\albucore\utils.py:113: UserWarning: HueSaturationValue: hue_shift and sat_shift are not applicable to grayscale image. Set them to 0 or use RGB image
#   result = func(img, *args, **kwargs)

# %% [markdown]
# # Segmentation model training

# %%
import segmentation_models as sm
from keras.models import Model
from keras.layers import Input, Conv2D
from keras.applications import EfficientNetB7

# segmentation_models could also use `tf.keras` if you do not have Keras installed
# or you could switch to other framework using `sm.set_framework('tf.keras')`
# Out:
# Segmentation Models: using `keras` framework.

# %%
BACKBONE = 'efficientnetb7'
BATCH_SIZE = 4
CLASSES = ['background', 'bone']
LR = 0.0001
EPOCHS = 100

# Define preprocessing function
preprocess_input = custom_preprocessing

# %%
# define network parameters
n_classes = 1 if len(CLASSES) == 1 else (len(CLASSES))  # case for binary and multiclass segmentation
activation = 'sigmoid' if n_classes == 1 else 'softmax'

#create model
model = sm.Unet(BACKBONE, classes=n_classes, activation=activation, encoder_weights='imagenet')

# %%
import keras.backend as K # type: ignore

# define optomizer
optim = keras.optimizers.Adam(LR) # type: ignore

class DiceLossWithClip(sm.losses.DiceLoss):
    def __init__(self, class_weights=None, **kwargs):
        super().__init__(class_weights=class_weights, **kwargs)

    def __call__(self, y_true, y_pred):
        dice_loss = super().__call__(y_true, y_pred)
        return K.clip(dice_loss, 0, 1)

# Segmentation models losses can be combined together by '+' and scaled by integer or float factor
# set class weights for dice_loss 
dice_loss = sm.losses.DiceLoss(class_weights=np.array([1, 1])) 
focal_loss = sm.losses.BinaryFocalLoss() if n_classes == 1 else sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

# actulally total_loss can be imported directly from library, above example just show you how to manipulate with losses
# total_loss = sm.losses.binary_focal_dice_loss # or sm.losses.categorical_focal_dice_loss 

metrics = [sm.metrics.IOUScore(threshold=0.5), sm.metrics.FScore(threshold=0.5)]

# compile keras model with defined optimozer, loss and metrics
model.compile(optim, total_loss, metrics)

# %%
# Dataset for train images
train_dataset = Dataset(
    x_train_dir, 
    y_train_dir, 
    classes=CLASSES, 
    augmentation=get_training_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
)

# Dataset for validation images
valid_dataset = Dataset(
    x_valid_dir, 
    y_valid_dir, 
    classes=CLASSES, 
    augmentation=get_validation_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
)

train_dataloader = Dataloder(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
valid_dataloader = Dataloder(valid_dataset, batch_size=1, shuffle=False)

# check shapes for errors
print("Shape of images in train_dataloader:", train_dataloader[0][0].shape)
print("Shape of masks in train_dataloader:", train_dataloader[0][1].shape)

assert train_dataloader[0][0].shape == (BATCH_SIZE, 512, 512, 3)
assert train_dataloader[0][1].shape == (BATCH_SIZE, 512, 512, n_classes)

# define callbacks for learning rate scheduling and best checkpoints saving
callbacks = [
    keras.callbacks.ModelCheckpoint('./sacrum_unet_effB7_1129.h5', save_best_only=True, mode='min'), # type: ignore
    keras.callbacks.ReduceLROnPlateau(), # type: ignore
]
# Out:
# Shape of images in train_dataloader: (8, 512, 512, 3)
# Shape of masks in train_dataloader: (8, 512, 512, 2)

# %%
# train model
history = model.fit(
    train_dataloader, 
    steps_per_epoch=len(train_dataloader), 
    epochs=EPOCHS, 
    callbacks=callbacks, 
    validation_data=valid_dataloader, 
    validation_steps=len(valid_dataloader),
)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 20s 645ms/step - loss: 0.6625 - iou_score: 0.3496 - f1-score: 0.4238 - val_loss: 0.6724 - val_iou_score: 0.3424 - val_f1-score: 0.4249 - lr: 1.0000e-04
# Epoch 2/100
# 8/8 [==============================] - 3s 318ms/step - loss: 0.6441 - iou_score: 0.3454 - f1-score: 0.4222 - val_loss: 0.7293 - val_iou_score: 0.1001 - val_f1-score: 0.1710 - lr: 1.0000e-04
# Epoch 3/100
# 8/8 [==============================] - 3s 320ms/step - loss: 0.6310 - iou_score: 0.3636 - f1-score: 0.4378 - val_loss: 0.8130 - val_iou_score: 0.0205 - val_f1-score: 0.0401 - lr: 1.0000e-04
# Epoch 4/100
# 8/8 [==============================] - 3s 323ms/step - loss: 0.6143 - iou_score: 0.3956 - f1-score: 0.4641 - val_loss: 0.8671 - val_iou_score: 0.0144 - val_f1-score: 0.0284 - lr: 1.0000e-04
# Epoch 5/100
# 8/8 [==============================] - 3s 312ms/step - loss: 0.6036 - iou_score: 0.4338 - f1-score: 0.4963 - val_loss: 0.8537 - val_iou_score: 0.0166 - val_f1-score: 0.0327 - lr: 1.0000e-04
# Epoch 6/100
# 8/8 [==============================] - 3s 314ms/step - loss: 0.5884 - iou_score: 0.4645 - f1-score: 0.5288 - val_loss: 0.7903 - val_iou_score: 0.1277 - val_f1-score: 0.2089 - lr: 1.0000e-04
# Epoch 7/100
# 8/8 [==============================] - 3s 314ms/step - loss: 0.5760 - iou_score: 0.4731 - f1-score: 0.5410 - val_loss: 0.7233 - val_iou_score: 0.2797 - val_f1-score: 0.3734 - lr: 1.0000e-04
# Epoch 8/100
# 8/8 [==============================] - 3s 315ms/step - loss: 0.5639 - iou_score: 0.5032 - f1-score: 0.5694 - val_loss: 0.6769 - val_iou_score: 0.3863 - val_f1-score: 0.4639 - lr: 1.0000e-04
# Epoch 9/100
# 8/8 [==============================] - 3s 350ms/step - loss: 0.5591 - iou_score: 0.5151 - f1-score: 0.5880 - val_loss: 0.6272 - val_iou_score: 0.4646 - val_f1-score: 0.5313 - lr: 1.0000e-04
# Epoch 10/100
# 8/8 [==============================] - 3s 348ms/step - loss: 0.5479 - iou_score: 0.5393 - f1-score: 0.6121 - val_loss: 0.5976 - val_iou_score: 0.5468 - val_f1-score: 0.6197 - lr: 1.0000e-04
# Epoch 11/100
# 8/8 [==============================] - 3s 313ms/step - loss: 0.5400 - iou_score: 0.5558 - f1-score: 0.6407 - val_loss: 0.5994 - val_iou_score: 0.5598 - val_f1-score: 0.6350 - lr: 1.0000e-04
# Epoch 12/100
# 8/8 [==============================] - 3s 339ms/step - loss: 0.5300 - iou_score: 0.5865 - f1-score: 0.6820 - val_loss: 0.5810 - val_iou_score: 0.5984 - val_f1-score: 0.6799 - lr: 1.0000e-04
# Epoch 13/100
# 8/8 [==============================] - 3s 342ms/step - loss: 0.5170 - iou_score: 0.6102 - f1-score: 0.7091 - val_loss: 0.5685 - val_iou_score: 0.6107 - val_f1-score: 0.6942 - lr: 1.0000e-04
# Epoch 14/100
# 8/8 [==============================] - 3s 351ms/step - loss: 0.5129 - iou_score: 0.6094 - f1-score: 0.7072 - val_loss: 0.5396 - val_iou_score: 0.6642 - val_f1-score: 0.7524 - lr: 1.0000e-04
# Epoch 15/100
# 8/8 [==============================] - 3s 342ms/step - loss: 0.5065 - iou_score: 0.6250 - f1-score: 0.7237 - val_loss: 0.5067 - val_iou_score: 0.6855 - val_f1-score: 0.7742 - lr: 1.0000e-04
# Epoch 16/100
# 8/8 [==============================] - 3s 341ms/step - loss: 0.4951 - iou_score: 0.6362 - f1-score: 0.7338 - val_loss: 0.4765 - val_iou_score: 0.7167 - val_f1-score: 0.8044 - lr: 1.0000e-04
# Epoch 17/100
# 8/8 [==============================] - 3s 343ms/step - loss: 0.4935 - iou_score: 0.6267 - f1-score: 0.7229 - val_loss: 0.4517 - val_iou_score: 0.7049 - val_f1-score: 0.7933 - lr: 1.0000e-04
# Epoch 18/100
# 8/8 [==============================] - 3s 346ms/step - loss: 0.4944 - iou_score: 0.6252 - f1-score: 0.7243 - val_loss: 0.4290 - val_iou_score: 0.7113 - val_f1-score: 0.7992 - lr: 1.0000e-04
# Epoch 19/100
# 8/8 [==============================] - 3s 340ms/step - loss: 0.4691 - iou_score: 0.6689 - f1-score: 0.7660 - val_loss: 0.4119 - val_iou_score: 0.7116 - val_f1-score: 0.7996 - lr: 1.0000e-04
# Epoch 20/100
# 8/8 [==============================] - 3s 348ms/step - loss: 0.4687 - iou_score: 0.6516 - f1-score: 0.7501 - val_loss: 0.3740 - val_iou_score: 0.7573 - val_f1-score: 0.8406 - lr: 1.0000e-04
# Epoch 21/100
# 8/8 [==============================] - 3s 349ms/step - loss: 0.4629 - iou_score: 0.6532 - f1-score: 0.7543 - val_loss: 0.3633 - val_iou_score: 0.7019 - val_f1-score: 0.7903 - lr: 1.0000e-04
# Epoch 22/100
# 8/8 [==============================] - 3s 345ms/step - loss: 0.4539 - iou_score: 0.6577 - f1-score: 0.7600 - val_loss: 0.3224 - val_iou_score: 0.7716 - val_f1-score: 0.8527 - lr: 1.0000e-04
# Epoch 23/100
# 8/8 [==============================] - 3s 320ms/step - loss: 0.4554 - iou_score: 0.6472 - f1-score: 0.7481 - val_loss: 0.3248 - val_iou_score: 0.7021 - val_f1-score: 0.7905 - lr: 1.0000e-04
# Epoch 24/100
# 8/8 [==============================] - 3s 338ms/step - loss: 0.4536 - iou_score: 0.6431 - f1-score: 0.7448 - val_loss: 0.2830 - val_iou_score: 0.7776 - val_f1-score: 0.8579 - lr: 1.0000e-04
# Epoch 25/100
# 8/8 [==============================] - 3s 314ms/step - loss: 0.4416 - iou_score: 0.6529 - f1-score: 0.7482 - val_loss: 0.2906 - val_iou_score: 0.7456 - val_f1-score: 0.8304 - lr: 1.0000e-04
# Epoch 26/100
# 8/8 [==============================] - 3s 337ms/step - loss: 0.4264 - iou_score: 0.6678 - f1-score: 0.7656 - val_loss: 0.2760 - val_iou_score: 0.7676 - val_f1-score: 0.8495 - lr: 1.0000e-04
# Epoch 27/100
# 8/8 [==============================] - 3s 337ms/step - loss: 0.4140 - iou_score: 0.6833 - f1-score: 0.7776 - val_loss: 0.2659 - val_iou_score: 0.7780 - val_f1-score: 0.8581 - lr: 1.0000e-04
# Epoch 28/100
# 8/8 [==============================] - 3s 310ms/step - loss: 0.4199 - iou_score: 0.6562 - f1-score: 0.7564 - val_loss: 0.2737 - val_iou_score: 0.7481 - val_f1-score: 0.8326 - lr: 1.0000e-04
# Epoch 29/100
# 8/8 [==============================] - 3s 314ms/step - loss: 0.4300 - iou_score: 0.6374 - f1-score: 0.7345 - val_loss: 0.2690 - val_iou_score: 0.7790 - val_f1-score: 0.8588 - lr: 1.0000e-04
# Epoch 30/100
# 8/8 [==============================] - 3s 319ms/step - loss: 0.4084 - iou_score: 0.6535 - f1-score: 0.7543 - val_loss: 0.2852 - val_iou_score: 0.7600 - val_f1-score: 0.8432 - lr: 1.0000e-04
# Epoch 31/100
# 8/8 [==============================] - 3s 316ms/step - loss: 0.3954 - iou_score: 0.6680 - f1-score: 0.7644 - val_loss: 0.3034 - val_iou_score: 0.7525 - val_f1-score: 0.8366 - lr: 1.0000e-04
# Epoch 32/100
# 8/8 [==============================] - 3s 309ms/step - loss: 0.3921 - iou_score: 0.6702 - f1-score: 0.7709 - val_loss: 0.3111 - val_iou_score: 0.7569 - val_f1-score: 0.8403 - lr: 1.0000e-04
# Epoch 33/100
# 8/8 [==============================] - 3s 313ms/step - loss: 0.3855 - iou_score: 0.6690 - f1-score: 0.7696 - val_loss: 0.3074 - val_iou_score: 0.7607 - val_f1-score: 0.8438 - lr: 1.0000e-04
# Epoch 34/100
# 8/8 [==============================] - 3s 326ms/step - loss: 0.3603 - iou_score: 0.6995 - f1-score: 0.7961 - val_loss: 0.3071 - val_iou_score: 0.7889 - val_f1-score: 0.8669 - lr: 1.0000e-04
# Epoch 35/100
# 8/8 [==============================] - 3s 314ms/step - loss: 0.3441 - iou_score: 0.7086 - f1-score: 0.8064 - val_loss: 0.3123 - val_iou_score: 0.7864 - val_f1-score: 0.8648 - lr: 1.0000e-04
# Epoch 36/100
# 8/8 [==============================] - 3s 313ms/step - loss: 0.3635 - iou_score: 0.6698 - f1-score: 0.7652 - val_loss: 0.3012 - val_iou_score: 0.7964 - val_f1-score: 0.8728 - lr: 1.0000e-04
# Epoch 37/100
# 8/8 [==============================] - 3s 318ms/step - loss: 0.3387 - iou_score: 0.7042 - f1-score: 0.8014 - val_loss: 0.2829 - val_iou_score: 0.7798 - val_f1-score: 0.8595 - lr: 1.0000e-04
# Epoch 38/100
# 8/8 [==============================] - 3s 320ms/step - loss: 0.3336 - iou_score: 0.6930 - f1-score: 0.7935 - val_loss: 0.2971 - val_iou_score: 0.7799 - val_f1-score: 0.8595 - lr: 1.0000e-05
# Epoch 39/100
# 8/8 [==============================] - 3s 312ms/step - loss: 0.3317 - iou_score: 0.6990 - f1-score: 0.8013 - val_loss: 0.3081 - val_iou_score: 0.7854 - val_f1-score: 0.8640 - lr: 1.0000e-05
# Epoch 40/100
# 8/8 [==============================] - 3s 311ms/step - loss: 0.3408 - iou_score: 0.6961 - f1-score: 0.7936 - val_loss: 0.3113 - val_iou_score: 0.7889 - val_f1-score: 0.8667 - lr: 1.0000e-05
# Epoch 41/100
# 8/8 [==============================] - 3s 315ms/step - loss: 0.3426 - iou_score: 0.6892 - f1-score: 0.7860 - val_loss: 0.3126 - val_iou_score: 0.7878 - val_f1-score: 0.8659 - lr: 1.0000e-05
# Epoch 42/100
# 8/8 [==============================] - 3s 317ms/step - loss: 0.3189 - iou_score: 0.7107 - f1-score: 0.8074 - val_loss: 0.3179 - val_iou_score: 0.7920 - val_f1-score: 0.8692 - lr: 1.0000e-05
# Epoch 43/100
# 8/8 [==============================] - 3s 308ms/step - loss: 0.3635 - iou_score: 0.6657 - f1-score: 0.7637 - val_loss: 0.3156 - val_iou_score: 0.7946 - val_f1-score: 0.8713 - lr: 1.0000e-05
# Epoch 44/100
# 8/8 [==============================] - 3s 315ms/step - loss: 0.3369 - iou_score: 0.6907 - f1-score: 0.7916 - val_loss: 0.3211 - val_iou_score: 0.7911 - val_f1-score: 0.8685 - lr: 1.0000e-05
# Epoch 45/100
# 8/8 [==============================] - 3s 313ms/step - loss: 0.3213 - iou_score: 0.7085 - f1-score: 0.8039 - val_loss: 0.3336 - val_iou_score: 0.7873 - val_f1-score: 0.8655 - lr: 1.0000e-05
# Epoch 46/100
# 8/8 [==============================] - 3s 317ms/step - loss: 0.3088 - iou_score: 0.7232 - f1-score: 0.8204 - val_loss: 0.3401 - val_iou_score: 0.7907 - val_f1-score: 0.8682 - lr: 1.0000e-05
# Epoch 47/100
# 8/8 [==============================] - 3s 326ms/step - loss: 0.3237 - iou_score: 0.7066 - f1-score: 0.8046 - val_loss: 0.3461 - val_iou_score: 0.7916 - val_f1-score: 0.8689 - lr: 1.0000e-05
# Epoch 48/100
# 8/8 [==============================] - 3s 317ms/step - loss: 0.3534 - iou_score: 0.6730 - f1-score: 0.7700 - val_loss: 0.3593 - val_iou_score: 0.7898 - val_f1-score: 0.8675 - lr: 1.0000e-06
# Epoch 49/100
# 8/8 [==============================] - 3s 314ms/step - loss: 0.3311 - iou_score: 0.6897 - f1-score: 0.7900 - val_loss: 0.3627 - val_iou_score: 0.7888 - val_f1-score: 0.8667 - lr: 1.0000e-06
# Epoch 50/100
# 8/8 [==============================] - 3s 304ms/step - loss: 0.3269 - iou_score: 0.7001 - f1-score: 0.7993 - val_loss: 0.3606 - val_iou_score: 0.7885 - val_f1-score: 0.8665 - lr: 1.0000e-06
# Epoch 51/100
# 8/8 [==============================] - 3s 310ms/step - loss: 0.3164 - iou_score: 0.7167 - f1-score: 0.8140 - val_loss: 0.3558 - val_iou_score: 0.7881 - val_f1-score: 0.8662 - lr: 1.0000e-06
# Epoch 52/100
# 8/8 [==============================] - 3s 313ms/step - loss: 0.3418 - iou_score: 0.6838 - f1-score: 0.7801 - val_loss: 0.3511 - val_iou_score: 0.7885 - val_f1-score: 0.8664 - lr: 1.0000e-06
# Epoch 53/100
# 8/8 [==============================] - 3s 311ms/step - loss: 0.3265 - iou_score: 0.6987 - f1-score: 0.7956 - val_loss: 0.3597 - val_iou_score: 0.7873 - val_f1-score: 0.8655 - lr: 1.0000e-06
# Epoch 54/100
# 8/8 [==============================] - 3s 308ms/step - loss: 0.3418 - iou_score: 0.6765 - f1-score: 0.7766 - val_loss: 0.3550 - val_iou_score: 0.7866 - val_f1-score: 0.8650 - lr: 1.0000e-06
# Epoch 55/100
# 8/8 [==============================] - 3s 311ms/step - loss: 0.3208 - iou_score: 0.7066 - f1-score: 0.8043 - val_loss: 0.3486 - val_iou_score: 0.7871 - val_f1-score: 0.8654 - lr: 1.0000e-06
# Epoch 56/100
# 8/8 [==============================] - 3s 313ms/step - loss: 0.3085 - iou_score: 0.7230 - f1-score: 0.8196 - val_loss: 0.3455 - val_iou_score: 0.7868 - val_f1-score: 0.8651 - lr: 1.0000e-06
# Epoch 57/100
# 8/8 [==============================] - 3s 314ms/step - loss: 0.3444 - iou_score: 0.6793 - f1-score: 0.7742 - val_loss: 0.3415 - val_iou_score: 0.7860 - val_f1-score: 0.8645 - lr: 1.0000e-06
# Epoch 58/100
# 8/8 [==============================] - 3s 320ms/step - loss: 0.3180 - iou_score: 0.7084 - f1-score: 0.8040 - val_loss: 0.3349 - val_iou_score: 0.7853 - val_f1-score: 0.8639 - lr: 1.0000e-07
# Epoch 59/100
# 8/8 [==============================] - 3s 312ms/step - loss: 0.3138 - iou_score: 0.7153 - f1-score: 0.8129 - val_loss: 0.3286 - val_iou_score: 0.7851 - val_f1-score: 0.8638 - lr: 1.0000e-07
# Epoch 60/100
# 8/8 [==============================] - 3s 308ms/step - loss: 0.3187 - iou_score: 0.7042 - f1-score: 0.8010 - val_loss: 0.3215 - val_iou_score: 0.7851 - val_f1-score: 0.8638 - lr: 1.0000e-07
# Epoch 61/100
# 8/8 [==============================] - 3s 315ms/step - loss: 0.3471 - iou_score: 0.6753 - f1-score: 0.7735 - val_loss: 0.3144 - val_iou_score: 0.7846 - val_f1-score: 0.8634 - lr: 1.0000e-07
# Epoch 62/100
# 8/8 [==============================] - 3s 319ms/step - loss: 0.3061 - iou_score: 0.7326 - f1-score: 0.8274 - val_loss: 0.3089 - val_iou_score: 0.7846 - val_f1-score: 0.8634 - lr: 1.0000e-07
# Epoch 63/100
# 8/8 [==============================] - 3s 306ms/step - loss: 0.3194 - iou_score: 0.7104 - f1-score: 0.8055 - val_loss: 0.3047 - val_iou_score: 0.7852 - val_f1-score: 0.8638 - lr: 1.0000e-07
# Epoch 64/100
# 8/8 [==============================] - 3s 322ms/step - loss: 0.3311 - iou_score: 0.6926 - f1-score: 0.7898 - val_loss: 0.2993 - val_iou_score: 0.7850 - val_f1-score: 0.8636 - lr: 1.0000e-07
# Epoch 65/100
# 8/8 [==============================] - 3s 310ms/step - loss: 0.3428 - iou_score: 0.6819 - f1-score: 0.7815 - val_loss: 0.2947 - val_iou_score: 0.7843 - val_f1-score: 0.8631 - lr: 1.0000e-07
# Epoch 66/100
# 8/8 [==============================] - 3s 319ms/step - loss: 0.3453 - iou_score: 0.6801 - f1-score: 0.7812 - val_loss: 0.2905 - val_iou_score: 0.7840 - val_f1-score: 0.8629 - lr: 1.0000e-07
# Epoch 67/100
# 8/8 [==============================] - 3s 315ms/step - loss: 0.3525 - iou_score: 0.6681 - f1-score: 0.7691 - val_loss: 0.2864 - val_iou_score: 0.7834 - val_f1-score: 0.8623 - lr: 1.0000e-07
# Epoch 68/100
# 8/8 [==============================] - 3s 311ms/step - loss: 0.3115 - iou_score: 0.7207 - f1-score: 0.8179 - val_loss: 0.2832 - val_iou_score: 0.7837 - val_f1-score: 0.8626 - lr: 1.0000e-08
# Epoch 69/100
# 8/8 [==============================] - 3s 311ms/step - loss: 0.3088 - iou_score: 0.7181 - f1-score: 0.8148 - val_loss: 0.2797 - val_iou_score: 0.7845 - val_f1-score: 0.8632 - lr: 1.0000e-08
# Epoch 70/100
# 8/8 [==============================] - 3s 314ms/step - loss: 0.3422 - iou_score: 0.6864 - f1-score: 0.7835 - val_loss: 0.2742 - val_iou_score: 0.7842 - val_f1-score: 0.8630 - lr: 1.0000e-08
# Epoch 71/100
# 8/8 [==============================] - 3s 311ms/step - loss: 0.3164 - iou_score: 0.7163 - f1-score: 0.8102 - val_loss: 0.2691 - val_iou_score: 0.7842 - val_f1-score: 0.8630 - lr: 1.0000e-08
# Epoch 72/100
# 8/8 [==============================] - 3s 311ms/step - loss: 0.3353 - iou_score: 0.6899 - f1-score: 0.7890 - val_loss: 0.2664 - val_iou_score: 0.7843 - val_f1-score: 0.8631 - lr: 1.0000e-08
# Epoch 73/100
# 8/8 [==============================] - 3s 334ms/step - loss: 0.3248 - iou_score: 0.7047 - f1-score: 0.8020 - val_loss: 0.2619 - val_iou_score: 0.7847 - val_f1-score: 0.8634 - lr: 1.0000e-08
# Epoch 74/100
# 8/8 [==============================] - 3s 353ms/step - loss: 0.3247 - iou_score: 0.7031 - f1-score: 0.8019 - val_loss: 0.2607 - val_iou_score: 0.7853 - val_f1-score: 0.8639 - lr: 1.0000e-08
# Epoch 75/100
# 8/8 [==============================] - 3s 346ms/step - loss: 0.3432 - iou_score: 0.6794 - f1-score: 0.7782 - val_loss: 0.2581 - val_iou_score: 0.7854 - val_f1-score: 0.8640 - lr: 1.0000e-08
# Epoch 76/100
# 8/8 [==============================] - 3s 340ms/step - loss: 0.3226 - iou_score: 0.7053 - f1-score: 0.8024 - val_loss: 0.2553 - val_iou_score: 0.7858 - val_f1-score: 0.8643 - lr: 1.0000e-08
# Epoch 77/100
# 8/8 [==============================] - 3s 354ms/step - loss: 0.3519 - iou_score: 0.6779 - f1-score: 0.7736 - val_loss: 0.2537 - val_iou_score: 0.7862 - val_f1-score: 0.8646 - lr: 1.0000e-08
# Epoch 78/100
# 8/8 [==============================] - 3s 349ms/step - loss: 0.3229 - iou_score: 0.7083 - f1-score: 0.8019 - val_loss: 0.2523 - val_iou_score: 0.7861 - val_f1-score: 0.8645 - lr: 1.0000e-08
# Epoch 79/100
# 8/8 [==============================] - 3s 343ms/step - loss: 0.3074 - iou_score: 0.7309 - f1-score: 0.8255 - val_loss: 0.2507 - val_iou_score: 0.7866 - val_f1-score: 0.8650 - lr: 1.0000e-08
# Epoch 80/100
# 8/8 [==============================] - 3s 349ms/step - loss: 0.3137 - iou_score: 0.7105 - f1-score: 0.8098 - val_loss: 0.2501 - val_iou_score: 0.7868 - val_f1-score: 0.8651 - lr: 1.0000e-08
# Epoch 81/100
# 8/8 [==============================] - 3s 349ms/step - loss: 0.3195 - iou_score: 0.7094 - f1-score: 0.8065 - val_loss: 0.2492 - val_iou_score: 0.7868 - val_f1-score: 0.8652 - lr: 1.0000e-08
# Epoch 82/100
# 8/8 [==============================] - 3s 315ms/step - loss: 0.3198 - iou_score: 0.7099 - f1-score: 0.8068 - val_loss: 0.2495 - val_iou_score: 0.7871 - val_f1-score: 0.8653 - lr: 1.0000e-08
# Epoch 83/100
# 8/8 [==============================] - 3s 352ms/step - loss: 0.3268 - iou_score: 0.6965 - f1-score: 0.7920 - val_loss: 0.2489 - val_iou_score: 0.7874 - val_f1-score: 0.8656 - lr: 1.0000e-08
# Epoch 84/100
# 8/8 [==============================] - 3s 353ms/step - loss: 0.3188 - iou_score: 0.7075 - f1-score: 0.8054 - val_loss: 0.2486 - val_iou_score: 0.7877 - val_f1-score: 0.8659 - lr: 1.0000e-08
# Epoch 85/100
# 8/8 [==============================] - 3s 345ms/step - loss: 0.3003 - iou_score: 0.7367 - f1-score: 0.8315 - val_loss: 0.2485 - val_iou_score: 0.7885 - val_f1-score: 0.8665 - lr: 1.0000e-08
# Epoch 86/100
# 8/8 [==============================] - 3s 340ms/step - loss: 0.3187 - iou_score: 0.7061 - f1-score: 0.8046 - val_loss: 0.2479 - val_iou_score: 0.7888 - val_f1-score: 0.8668 - lr: 1.0000e-08
# Epoch 87/100
# 8/8 [==============================] - 3s 340ms/step - loss: 0.3466 - iou_score: 0.6809 - f1-score: 0.7761 - val_loss: 0.2477 - val_iou_score: 0.7884 - val_f1-score: 0.8664 - lr: 1.0000e-08
# Epoch 88/100
# 8/8 [==============================] - 3s 315ms/step - loss: 0.3310 - iou_score: 0.6932 - f1-score: 0.7908 - val_loss: 0.2478 - val_iou_score: 0.7881 - val_f1-score: 0.8662 - lr: 1.0000e-08
# Epoch 89/100
# 8/8 [==============================] - 3s 348ms/step - loss: 0.3348 - iou_score: 0.6880 - f1-score: 0.7829 - val_loss: 0.2477 - val_iou_score: 0.7877 - val_f1-score: 0.8659 - lr: 1.0000e-08
# Epoch 90/100
# 8/8 [==============================] - 3s 319ms/step - loss: 0.3298 - iou_score: 0.6949 - f1-score: 0.7951 - val_loss: 0.2479 - val_iou_score: 0.7877 - val_f1-score: 0.8659 - lr: 1.0000e-08
# Epoch 91/100
# 8/8 [==============================] - 3s 314ms/step - loss: 0.3200 - iou_score: 0.7101 - f1-score: 0.8092 - val_loss: 0.2481 - val_iou_score: 0.7880 - val_f1-score: 0.8661 - lr: 1.0000e-08
# Epoch 92/100
# 8/8 [==============================] - 3s 343ms/step - loss: 0.3357 - iou_score: 0.6956 - f1-score: 0.7926 - val_loss: 0.2476 - val_iou_score: 0.7876 - val_f1-score: 0.8657 - lr: 1.0000e-08
# Epoch 93/100
# 8/8 [==============================] - 3s 313ms/step - loss: 0.3120 - iou_score: 0.7184 - f1-score: 0.8136 - val_loss: 0.2478 - val_iou_score: 0.7880 - val_f1-score: 0.8661 - lr: 1.0000e-08
# Epoch 94/100
# 8/8 [==============================] - 3s 348ms/step - loss: 0.3114 - iou_score: 0.7198 - f1-score: 0.8171 - val_loss: 0.2475 - val_iou_score: 0.7882 - val_f1-score: 0.8663 - lr: 1.0000e-08
# Epoch 95/100
# 8/8 [==============================] - 3s 374ms/step - loss: 0.3210 - iou_score: 0.7040 - f1-score: 0.8025 - val_loss: 0.2474 - val_iou_score: 0.7884 - val_f1-score: 0.8664 - lr: 1.0000e-08
# Epoch 96/100
# 8/8 [==============================] - 3s 337ms/step - loss: 0.3353 - iou_score: 0.6881 - f1-score: 0.7899 - val_loss: 0.2469 - val_iou_score: 0.7883 - val_f1-score: 0.8664 - lr: 1.0000e-08
# Epoch 97/100
# 8/8 [==============================] - 3s 316ms/step - loss: 0.3307 - iou_score: 0.7010 - f1-score: 0.7958 - val_loss: 0.2471 - val_iou_score: 0.7885 - val_f1-score: 0.8665 - lr: 1.0000e-08
# Epoch 98/100
# 8/8 [==============================] - 3s 314ms/step - loss: 0.3242 - iou_score: 0.7036 - f1-score: 0.7975 - val_loss: 0.2469 - val_iou_score: 0.7884 - val_f1-score: 0.8664 - lr: 1.0000e-08
# Epoch 99/100
# 8/8 [==============================] - 3s 316ms/step - loss: 0.3194 - iou_score: 0.7099 - f1-score: 0.8086 - val_loss: 0.2474 - val_iou_score: 0.7886 - val_f1-score: 0.8665 - lr: 1.0000e-08
# Epoch 100/100
# 8/8 [==============================] - 3s 315ms/step - loss: 0.3219 - iou_score: 0.7036 - f1-score: 0.8018 - val_loss: 0.2475 - val_iou_score: 0.7886 - val_f1-score: 0.8666 - lr: 1.0000e-08

# %%
# Plot training & validation iou_score values
plt.figure(figsize=(30, 10))
plt.subplot(121)
plt.plot(history.history['iou_score'])
plt.plot(history.history['val_iou_score'])
plt.title('Model iou_score')
plt.ylabel('iou_score')
plt.xlabel('Epoch')
plt.legend(['Train', 'Valid'], loc='upper left')

# Plot training & validation loss values
plt.subplot(122)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Valid'], loc='upper left')
plt.show()

# %% [markdown]
# # Model Evaluation

# %%
test_dataset = Dataset(
    x_test_dir, 
    y_test_dir, 
    classes=CLASSES, 
    augmentation=get_validation_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
)

test_dataloader = Dataloder(test_dataset, batch_size=1, shuffle=False)

# %%
# load best weights
model.load_weights('sacrum_unet_effB7_1129.h5')

# %%
scores = model.evaluate_generator(test_dataloader)

print("Loss: {:.5}".format(scores[0]))
for metric, value in zip(metrics, scores[1:]):
    print("mean {}: {:.5}".format(metric.__name__, value))
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13072\3518042878.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   scores = model.evaluate_generator(test_dataloader)
# Loss: 0.21943
# mean iou_score: 0.82642
# mean f1-score: 0.89574

# %% [markdown]
# # Visualization of results on test dataset

# %%
# Define a function to convert mask to color
def mask_to_color(mask, num_classes=2):
    """
    Convert a mask with shape (H, W, num_classes) to a color image.
    """
    colors = np.array([
        [0, 0, 0],  # background
        [255, 255, 255],  # bone
    ])
    mask = np.argmax(mask, axis=-1)
    color_mask = np.zeros((mask.shape[0], mask.shape[1], 3), dtype=np.uint8)
    for c in range(num_classes):
        color_mask[mask == c] = colors[c]
    return color_mask

# helper function for data visualization
def visualize(**images):
    """PLot images in one row."""
    n = len(images)
    plt.figure(figsize=(16, 5))
    for i, (name, image) in enumerate(images.items()):
        plt.subplot(1, n, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.title(' '.join(name.split('_')).title())
        if name == 'image':
            plt.imshow(image, cmap='gray')
        else:
            plt.imshow(mask_to_color(image))
    plt.show()

# %%
n = 2
ids = np.random.choice(np.arange(len(test_dataset)), size=n)

for i in ids:
    
    image, gt_mask = test_dataset[i]
    image = np.expand_dims(image, axis=0)
    pr_mask = model.predict(image)
    
    visualize(
        image=denormalize(image.squeeze()),
        gt_mask=gt_mask.squeeze(),
        pr_mask=pr_mask.squeeze(),
    )
# Out:
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step

# %%
import keras.backend as K

# 每次訓練後清理 Keras 會話
def clear_keras_session():
    K.clear_session()
    
clear_keras_session()
