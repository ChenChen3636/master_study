# %% [markdown]
# ### Reqirements
# - keras >= 2.2.0 or tensorflow >= 1.13
# - segmenation-models==1.0.*
# - albumentations==0.3.0

# %%
# Install required libs

### please update Albumentations to version>=0.3.0 for `Lambda` transform support
# !pip install -U albumentations>=0.3.0 --user 
# !pip install -U --pre segmentation-models --user
# Out:
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: segmentation-models in c:\users\user\appdata\roaming\python\python38\site-packages (1.0.1)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in c:\users\user\appdata\roaming\python\python38\site-packages (from segmentation-models) (1.0.8)
# Requirement already satisfied: image-classifiers==1.0.0 in c:\users\user\appdata\roaming\python\python38\site-packages (from segmentation-models) (1.0.0)
# Requirement already satisfied: efficientnet==1.0.0 in c:\users\user\appdata\roaming\python\python38\site-packages (from segmentation-models) (1.0.0)
# Requirement already satisfied: scikit-image in c:\users\user\appdata\roaming\python\python38\site-packages (from efficientnet==1.0.0->segmentation-models) (0.21.0)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\user\appdata\roaming\python\python38\site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.24.4)
# Requirement already satisfied: h5py in c:\users\user\appdata\local\programs\python\python38\lib\site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (3.11.0)
# Requirement already satisfied: scipy>=1.8 in c:\users\user\appdata\local\programs\python\python38\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.10.1)
# Requirement already satisfied: networkx>=2.8 in c:\users\user\appdata\roaming\python\python38\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (3.1)
# Requirement already satisfied: pillow>=9.0.1 in c:\users\user\appdata\local\programs\python\python38\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (10.3.0)
# Requirement already satisfied: imageio>=2.27 in c:\users\user\appdata\roaming\python\python38\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.34.2)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\user\appdata\roaming\python\python38\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2023.7.10)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\user\appdata\roaming\python\python38\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.4.1)
# Requirement already satisfied: packaging>=21 in c:\users\user\appdata\local\programs\python\python38\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (24.0)
# Requirement already satisfied: lazy_loader>=0.2 in c:\users\user\appdata\roaming\python\python38\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (0.4)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Loading dataset

# %%
import os
import tensorflow as tf
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

import cv2
import keras
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Num GPUs Available:  1

# %%
DATA_DIR = 'C:\ellie\study\models\Sacrum'

# %%
x_train_dir = os.path.join(DATA_DIR, 'train')
y_train_dir = os.path.join(DATA_DIR, 'trainannot')

x_valid_dir = os.path.join(DATA_DIR, 'val')
y_valid_dir = os.path.join(DATA_DIR, 'valannot')

x_test_dir = os.path.join(DATA_DIR, 'test')
y_test_dir = os.path.join(DATA_DIR, 'testannot')

# %% [markdown]
# # Dataloader and utility functions

# %%
# helper function for data visualization
def visualize(**images):
    """PLot images in one row."""
    n = len(images)
    plt.figure(figsize=(16, 5))
    for i, (name, image) in enumerate(images.items()):
        plt.subplot(1, n, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.title(' '.join(name.split('_')).title())
        plt.imshow(image, cmap='gray')
    plt.show()
    
# helper function for data visualization    
def denormalize(x):
    """Scale image to range 0..1 for correct plot"""
    x_max = np.percentile(x, 98)
    x_min = np.percentile(x, 2)    
    x = (x - x_min) / (x_max - x_min)
    x = x.clip(0, 1)
    return x

# classes for data loading and preprocessing
class Dataset:
    
    CLASSES = ['background', 'bone']
    
    def __init__(
            self, 
            images_dir, 
            masks_dir, 
            classes=None, 
            augmentation=None, 
            preprocessing=None,
    ):
        self.ids = os.listdir(images_dir)
        self.images_fps = [os.path.join(images_dir, image_id) for image_id in self.ids]
        self.masks_fps = [os.path.join(masks_dir, image_id.replace('.jpg', '.npy')) for image_id in self.ids]
        
        # convert str names to class values on masks
        self.class_values = [self.CLASSES.index(cls.lower()) for cls in classes] # type: ignore
        
        self.augmentation = augmentation
        self.preprocessing = preprocessing
    
    def __getitem__(self, i):
        
        # read data
        image = cv2.imread(self.images_fps[i], cv2.IMREAD_GRAYSCALE)
        image = np.expand_dims(image, axis=-1)  # 添加通道維度
        mask = np.load(self.masks_fps[i])
        
        # Process the mask: set all non-background (non-zero) labels to 1
        mask = np.where(mask != 0, 1, 0).astype('float')  # Background = 0, Bone = 1
        
         # Extract relevant classes (background and bone)
        masks = [(mask == v) for v in self.class_values]
        mask = np.stack(masks, axis=-1).astype('float')
        
        # apply augmentations
        if self.augmentation:
            sample = self.augmentation(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
        
        # apply preprocessing
        if self.preprocessing:
            sample = self.preprocessing(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
            
        return image, mask
        
    def __len__(self):
        return len(self.ids)
    
    
class Dataloder(keras.utils.Sequence): # type: ignore
    """Load data from dataset and form batches
    
    Args:
        dataset: instance of Dataset class for image loading and preprocessing.
        batch_size: Integet number of images in batch.
        shuffle: Boolean, if `True` shuffle image indexes each epoch.
    """
    
    def __init__(self, dataset, batch_size=1, shuffle=False):
        self.dataset = dataset
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indexes = np.arange(len(dataset))
        self.on_epoch_end()

    def __getitem__(self, i):
        
        # collect batch data
        start = i * self.batch_size
        stop = (i + 1) * self.batch_size
        data = [self.dataset[j] for j in range(start, stop)]
        batch = [np.stack(samples, axis=0) for samples in zip(*data)]
        return batch
    
    def __len__(self):
        """Denotes the number of batches per epoch"""
        return len(self.indexes) // self.batch_size
    
    def on_epoch_end(self):
        """Callback function to shuffle indexes each epoch"""
        if self.shuffle:
            self.indexes = np.random.permutation(self.indexes)

# %%
# Lets look at data we have
dataset = Dataset(x_train_dir, y_train_dir, classes=['background', 'bone'])

image, mask = dataset[0] # get some sample

# 可視化影像和標註
visualize(
    image=image, 
    background=mask[..., 0].squeeze(),
    bone_mask=mask[..., 1].squeeze()
)

# %% [markdown]
# ### Augmentations

# %%
import albumentations as A # type: ignore
# Out:
# C:\Users\User\AppData\Roaming\Python\Python38\site-packages\albumentations\__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.21 (you have 1.4.18). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %%
def round_clip_0_1(x, **kwargs):
    return x.round().clip(0, 1)

# define heavy augmentations
def get_training_augmentation():
    train_transform = [

        A.HorizontalFlip(p=0.3),
        A.ShiftScaleRotate(scale_limit=0.1, rotate_limit=0.1, shift_limit=0.1, p=0.5, border_mode=0),
        A.PadIfNeeded(min_height=512, min_width=512, always_apply=True, border_mode=cv2.BORDER_CONSTANT, value=0),
        A.GaussNoise(p=0.5),  
        
        A.OneOf(
            [
                A.CLAHE(p=1),
                A.RandomBrightnessContrast(brightness_limit=2, contrast_limit=0, p=1),
                A.RandomGamma(p=1),
            ],
            p=0.9,
        ),

        A.OneOf(
            [
                A.Sharpen(p=1),
                A.Blur(blur_limit=3, p=1),
                A.MotionBlur(blur_limit=3, p=1),
            ],
            p=0.9,
        ),

        A.OneOf(
            [
                A.RandomBrightnessContrast(brightness_limit=0, contrast_limit=2, p=1),
                A.HueSaturationValue(p=1),
            ],
            p=0.9,
        ),
        A.Lambda(mask=round_clip_0_1)
    ]
    return A.Compose(train_transform)


def get_validation_augmentation():
    test_transform = [
        A.PadIfNeeded(512, 512)
    ]
    return A.Compose(test_transform) # type: ignore

def get_preprocessing(preprocessing_fn):
    
    _transform = [
        A.Lambda(image=preprocessing_fn),
    ]
    return A.Compose(_transform) # type: ignore

def custom_preprocessing(image, **kwargs):
    """Apply preprocessing for grayscale images"""
    if image.shape[-1] == 1:
        image = np.repeat(image, 3, axis=-1)  # 將灰階影像複製成3個通道
    image = image.astype(np.float32) / 255.0
    return image

# %%
# Lets look at augmented data we have
dataset = Dataset(x_train_dir, y_train_dir, classes=['background', 'bone'], augmentation=get_training_augmentation())

image, mask = dataset[12] # get some sample
visualize(
    image=image, 
    background=mask[..., 0].squeeze(),
    bone_mask=mask[..., 1].squeeze()
)
# Out:
# C:\Users\User\AppData\Roaming\Python\Python38\site-packages\albucore\decorators.py:43: UserWarning: HueSaturationValue: hue_shift and sat_shift are not applicable to grayscale image. Set them to 0 or use RGB image
#   result = func(img, *args, **kwargs)

# %% [markdown]
# # Segmentation model training

# %%
import segmentation_models as sm
from keras.models import Model
from keras.layers import Input, Conv2D
from keras.applications import EfficientNetB7

# segmentation_models could also use `tf.keras` if you do not have Keras installed
# or you could switch to other framework using `sm.set_framework('tf.keras')`
# Out:
# Segmentation Models: using `keras` framework.

# %%
BACKBONE = 'efficientnetb7'
BATCH_SIZE = 4
CLASSES = ['background', 'bone']
LR = 0.0001
EPOCHS = 100

# Define preprocessing function
preprocess_input = custom_preprocessing

# %%
# define network parameters
n_classes = 1 if len(CLASSES) == 1 else (len(CLASSES))  # case for binary and multiclass segmentation
activation = 'sigmoid' if n_classes == 1 else 'softmax'

#create model
model = sm.Unet(BACKBONE, classes=n_classes, activation=activation, encoder_weights='imagenet')

# %%
import keras.backend as K # type: ignore

# define optomizer
optim = keras.optimizers.Adam(LR) # type: ignore

class DiceLossWithClip(sm.losses.DiceLoss):
    def __init__(self, class_weights=None, **kwargs):
        super().__init__(class_weights=class_weights, **kwargs)

    def __call__(self, y_true, y_pred):
        dice_loss = super().__call__(y_true, y_pred)
        return K.clip(dice_loss, 0, 1)

# Segmentation models losses can be combined together by '+' and scaled by integer or float factor
# set class weights for dice_loss 
dice_loss = sm.losses.DiceLoss(class_weights=np.array([1, 1])) 
focal_loss = sm.losses.BinaryFocalLoss() if n_classes == 1 else sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

# actulally total_loss can be imported directly from library, above example just show you how to manipulate with losses
# total_loss = sm.losses.binary_focal_dice_loss # or sm.losses.categorical_focal_dice_loss 

metrics = [sm.metrics.IOUScore(threshold=0.5), sm.metrics.FScore(threshold=0.5)]

# compile keras model with defined optimozer, loss and metrics
model.compile(optim, total_loss, metrics)

# %%
# Dataset for train images
train_dataset = Dataset(
    x_train_dir, 
    y_train_dir, 
    classes=CLASSES, 
    augmentation=get_training_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
)

# Dataset for validation images
valid_dataset = Dataset(
    x_valid_dir, 
    y_valid_dir, 
    classes=CLASSES, 
    augmentation=get_validation_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
)

train_dataloader = Dataloder(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
valid_dataloader = Dataloder(valid_dataset, batch_size=1, shuffle=False)

# check shapes for errors
print("Shape of images in train_dataloader:", train_dataloader[0][0].shape)
print("Shape of masks in train_dataloader:", train_dataloader[0][1].shape)

assert train_dataloader[0][0].shape == (BATCH_SIZE, 512, 512, 3)
assert train_dataloader[0][1].shape == (BATCH_SIZE, 512, 512, n_classes)

# define callbacks for learning rate scheduling and best checkpoints saving
callbacks = [
    keras.callbacks.ModelCheckpoint('./sacrum_unet_effB7_1129.h5', save_best_only=True, mode='min'), # type: ignore
    keras.callbacks.ReduceLROnPlateau(), # type: ignore
]
# Out:
# Shape of images in train_dataloader: (4, 512, 512, 3)
# Shape of masks in train_dataloader: (4, 512, 512, 2)

# %%
# train model
history = model.fit(
    train_dataloader, 
    steps_per_epoch=len(train_dataloader), 
    epochs=EPOCHS, 
    callbacks=callbacks, 
    validation_data=valid_dataloader, 
    validation_steps=len(valid_dataloader),
)
# Out:
# Epoch 1/100
# 17/17 [==============================] - 109s 4s/step - loss: 0.6561 - iou_score: 0.3140 - f1-score: 0.3880 - val_loss: 0.6141 - val_iou_score: 0.4904 - val_f1-score: 0.5023 - lr: 1.0000e-04
# Epoch 2/100
# 17/17 [==============================] - 37s 2s/step - loss: 0.6153 - iou_score: 0.4051 - f1-score: 0.4577 - val_loss: 0.6731 - val_iou_score: 0.2287 - val_f1-score: 0.3145 - lr: 1.0000e-04
# Epoch 3/100
# 17/17 [==============================] - 42s 2s/step - loss: 0.5934 - iou_score: 0.4368 - f1-score: 0.4823 - val_loss: 0.6846 - val_iou_score: 0.1992 - val_f1-score: 0.2861 - lr: 1.0000e-04
# Epoch 4/100
# 17/17 [==============================] - 42s 3s/step - loss: 0.5726 - iou_score: 0.4676 - f1-score: 0.5064 - val_loss: 0.6720 - val_iou_score: 0.2243 - val_f1-score: 0.3120 - lr: 1.0000e-04
# Epoch 5/100
# 17/17 [==============================] - 42s 3s/step - loss: 0.5601 - iou_score: 0.4813 - f1-score: 0.5271 - val_loss: 0.6415 - val_iou_score: 0.3337 - val_f1-score: 0.4051 - lr: 1.0000e-04
# Epoch 6/100
# 17/17 [==============================] - 54s 3s/step - loss: 0.5505 - iou_score: 0.4961 - f1-score: 0.5513 - val_loss: 0.6121 - val_iou_score: 0.4856 - val_f1-score: 0.5231 - lr: 1.0000e-04
# Epoch 7/100
# 17/17 [==============================] - 61s 4s/step - loss: 0.5438 - iou_score: 0.5053 - f1-score: 0.5738 - val_loss: 0.5816 - val_iou_score: 0.5576 - val_f1-score: 0.6174 - lr: 1.0000e-04
# Epoch 8/100
# 17/17 [==============================] - 61s 4s/step - loss: 0.5300 - iou_score: 0.5447 - f1-score: 0.6255 - val_loss: 0.5688 - val_iou_score: 0.5649 - val_f1-score: 0.6391 - lr: 1.0000e-04
# Epoch 9/100
# 17/17 [==============================] - 54s 3s/step - loss: 0.5057 - iou_score: 0.5870 - f1-score: 0.6809 - val_loss: 0.5335 - val_iou_score: 0.6102 - val_f1-score: 0.6933 - lr: 1.0000e-04
# Epoch 10/100
# 17/17 [==============================] - 54s 3s/step - loss: 0.4870 - iou_score: 0.6112 - f1-score: 0.7060 - val_loss: 0.5192 - val_iou_score: 0.6165 - val_f1-score: 0.7009 - lr: 1.0000e-04
# Epoch 11/100
# 17/17 [==============================] - 37s 2s/step - loss: 0.4724 - iou_score: 0.6172 - f1-score: 0.7188 - val_loss: 0.5461 - val_iou_score: 0.5472 - val_f1-score: 0.6207 - lr: 1.0000e-04
# Epoch 12/100
# 17/17 [==============================] - 53s 3s/step - loss: 0.4593 - iou_score: 0.6310 - f1-score: 0.7274 - val_loss: 0.5166 - val_iou_score: 0.5829 - val_f1-score: 0.6625 - lr: 1.0000e-04
# Epoch 13/100
# 17/17 [==============================] - 60s 4s/step - loss: 0.4280 - iou_score: 0.6549 - f1-score: 0.7553 - val_loss: 0.4809 - val_iou_score: 0.6790 - val_f1-score: 0.7683 - lr: 1.0000e-04
# Epoch 14/100
# 17/17 [==============================] - 56s 3s/step - loss: 0.4215 - iou_score: 0.6419 - f1-score: 0.7393 - val_loss: 0.4520 - val_iou_score: 0.7130 - val_f1-score: 0.8014 - lr: 1.0000e-04
# Epoch 15/100
# 17/17 [==============================] - 59s 4s/step - loss: 0.3937 - iou_score: 0.6640 - f1-score: 0.7657 - val_loss: 0.4411 - val_iou_score: 0.7176 - val_f1-score: 0.8057 - lr: 1.0000e-04
# Epoch 16/100
# 17/17 [==============================] - 54s 3s/step - loss: 0.3596 - iou_score: 0.6835 - f1-score: 0.7824 - val_loss: 0.4077 - val_iou_score: 0.7365 - val_f1-score: 0.8230 - lr: 1.0000e-04
# Epoch 17/100
# 17/17 [==============================] - 47s 3s/step - loss: 0.3882 - iou_score: 0.6270 - f1-score: 0.7175 - val_loss: 0.4079 - val_iou_score: 0.7494 - val_f1-score: 0.8344 - lr: 1.0000e-04
# Epoch 18/100
# 17/17 [==============================] - 65s 4s/step - loss: 0.3430 - iou_score: 0.6680 - f1-score: 0.7659 - val_loss: 0.3689 - val_iou_score: 0.7297 - val_f1-score: 0.8168 - lr: 1.0000e-04
# Epoch 19/100
# 17/17 [==============================] - 15s 908ms/step - loss: 0.3161 - iou_score: 0.6830 - f1-score: 0.7800 - val_loss: 0.3508 - val_iou_score: 0.7687 - val_f1-score: 0.8506 - lr: 1.0000e-04
# Epoch 20/100
# 17/17 [==============================] - 34s 2s/step - loss: 0.2914 - iou_score: 0.7015 - f1-score: 0.7968 - val_loss: 0.2883 - val_iou_score: 0.7692 - val_f1-score: 0.8511 - lr: 1.0000e-04
# Epoch 21/100
# 17/17 [==============================] - 59s 3s/step - loss: 0.2852 - iou_score: 0.6978 - f1-score: 0.7844 - val_loss: 0.2733 - val_iou_score: 0.7989 - val_f1-score: 0.8746 - lr: 1.0000e-04
# Epoch 22/100
# 17/17 [==============================] - 55s 3s/step - loss: 0.2505 - iou_score: 0.7208 - f1-score: 0.8148 - val_loss: 0.2502 - val_iou_score: 0.7761 - val_f1-score: 0.8565 - lr: 1.0000e-04
# Epoch 23/100
# 17/17 [==============================] - 59s 3s/step - loss: 0.2636 - iou_score: 0.6983 - f1-score: 0.7952 - val_loss: 0.2407 - val_iou_score: 0.7822 - val_f1-score: 0.8614 - lr: 1.0000e-04
# Epoch 24/100
# 17/17 [==============================] - 60s 4s/step - loss: 0.2603 - iou_score: 0.6955 - f1-score: 0.7909 - val_loss: 0.2160 - val_iou_score: 0.7922 - val_f1-score: 0.8694 - lr: 1.0000e-04
# Epoch 25/100
# 17/17 [==============================] - 60s 4s/step - loss: 0.2282 - iou_score: 0.7248 - f1-score: 0.8171 - val_loss: 0.1982 - val_iou_score: 0.8018 - val_f1-score: 0.8771 - lr: 1.0000e-04
# Epoch 26/100
# 17/17 [==============================] - 55s 3s/step - loss: 0.2380 - iou_score: 0.7090 - f1-score: 0.8032 - val_loss: 0.1836 - val_iou_score: 0.7955 - val_f1-score: 0.8719 - lr: 1.0000e-04
# Epoch 27/100
# 17/17 [==============================] - 54s 3s/step - loss: 0.2352 - iou_score: 0.7103 - f1-score: 0.8006 - val_loss: 0.1823 - val_iou_score: 0.7865 - val_f1-score: 0.8649 - lr: 1.0000e-04
# Epoch 28/100
# 17/17 [==============================] - 54s 3s/step - loss: 0.2285 - iou_score: 0.7155 - f1-score: 0.8055 - val_loss: 0.1700 - val_iou_score: 0.8005 - val_f1-score: 0.8759 - lr: 1.0000e-04
# Epoch 29/100
# 17/17 [==============================] - 55s 3s/step - loss: 0.2744 - iou_score: 0.6679 - f1-score: 0.7557 - val_loss: 0.1661 - val_iou_score: 0.8021 - val_f1-score: 0.8772 - lr: 1.0000e-04
# Epoch 30/100
# 17/17 [==============================] - 54s 3s/step - loss: 0.2037 - iou_score: 0.7343 - f1-score: 0.8262 - val_loss: 0.1557 - val_iou_score: 0.8084 - val_f1-score: 0.8821 - lr: 1.0000e-04
# Epoch 31/100
# 17/17 [==============================] - 12s 721ms/step - loss: 0.2401 - iou_score: 0.6925 - f1-score: 0.7874 - val_loss: 0.1578 - val_iou_score: 0.8031 - val_f1-score: 0.8781 - lr: 1.0000e-04
# Epoch 32/100
# 17/17 [==============================] - 54s 3s/step - loss: 0.2318 - iou_score: 0.6991 - f1-score: 0.7936 - val_loss: 0.1531 - val_iou_score: 0.8050 - val_f1-score: 0.8795 - lr: 1.0000e-04
# Epoch 33/100
# 17/17 [==============================] - 55s 3s/step - loss: 0.2159 - iou_score: 0.7141 - f1-score: 0.8094 - val_loss: 0.1489 - val_iou_score: 0.8015 - val_f1-score: 0.8767 - lr: 1.0000e-04
# Epoch 34/100
# 17/17 [==============================] - 59s 3s/step - loss: 0.2311 - iou_score: 0.6929 - f1-score: 0.7924 - val_loss: 0.1454 - val_iou_score: 0.8058 - val_f1-score: 0.8800 - lr: 1.0000e-04
# Epoch 35/100
# 17/17 [==============================] - 43s 3s/step - loss: 0.2421 - iou_score: 0.6919 - f1-score: 0.7796 - val_loss: 0.1457 - val_iou_score: 0.8040 - val_f1-score: 0.8785 - lr: 1.0000e-04
# Epoch 36/100
# 17/17 [==============================] - 60s 3s/step - loss: 0.2289 - iou_score: 0.7015 - f1-score: 0.7922 - val_loss: 0.1409 - val_iou_score: 0.8100 - val_f1-score: 0.8832 - lr: 1.0000e-04
# Epoch 37/100
# 17/17 [==============================] - 60s 4s/step - loss: 0.1870 - iou_score: 0.7413 - f1-score: 0.8331 - val_loss: 0.1399 - val_iou_score: 0.8097 - val_f1-score: 0.8829 - lr: 1.0000e-04
# Epoch 38/100
# 17/17 [==============================] - 43s 3s/step - loss: 0.2047 - iou_score: 0.7192 - f1-score: 0.8146 - val_loss: 0.1411 - val_iou_score: 0.8065 - val_f1-score: 0.8805 - lr: 1.0000e-04
# Epoch 39/100
# 17/17 [==============================] - 65s 4s/step - loss: 0.1949 - iou_score: 0.7306 - f1-score: 0.8239 - val_loss: 0.1389 - val_iou_score: 0.8093 - val_f1-score: 0.8826 - lr: 1.0000e-04
# Epoch 40/100
# 17/17 [==============================] - 54s 3s/step - loss: 0.2127 - iou_score: 0.7176 - f1-score: 0.8055 - val_loss: 0.1352 - val_iou_score: 0.8118 - val_f1-score: 0.8846 - lr: 1.0000e-04
# Epoch 41/100
# 17/17 [==============================] - 42s 3s/step - loss: 0.1798 - iou_score: 0.7471 - f1-score: 0.8372 - val_loss: 0.1354 - val_iou_score: 0.8092 - val_f1-score: 0.8826 - lr: 1.0000e-04
# Epoch 42/100
# 17/17 [==============================] - 42s 3s/step - loss: 0.2233 - iou_score: 0.7022 - f1-score: 0.7936 - val_loss: 0.1365 - val_iou_score: 0.8064 - val_f1-score: 0.8804 - lr: 1.0000e-04
# Epoch 43/100
# 17/17 [==============================] - 42s 3s/step - loss: 0.2233 - iou_score: 0.7026 - f1-score: 0.7934 - val_loss: 0.1446 - val_iou_score: 0.7942 - val_f1-score: 0.8707 - lr: 1.0000e-04
# Epoch 44/100
# 17/17 [==============================] - 37s 2s/step - loss: 0.1879 - iou_score: 0.7364 - f1-score: 0.8281 - val_loss: 0.1364 - val_iou_score: 0.8040 - val_f1-score: 0.8784 - lr: 1.0000e-04
# Epoch 45/100
# 17/17 [==============================] - 42s 2s/step - loss: 0.2194 - iou_score: 0.7090 - f1-score: 0.7957 - val_loss: 0.1360 - val_iou_score: 0.8041 - val_f1-score: 0.8786 - lr: 1.0000e-04
# Epoch 46/100
# 17/17 [==============================] - 54s 3s/step - loss: 0.2004 - iou_score: 0.7264 - f1-score: 0.8146 - val_loss: 0.1303 - val_iou_score: 0.8107 - val_f1-score: 0.8836 - lr: 1.0000e-04
# Epoch 47/100
# 17/17 [==============================] - 59s 3s/step - loss: 0.1968 - iou_score: 0.7261 - f1-score: 0.8185 - val_loss: 0.1286 - val_iou_score: 0.8127 - val_f1-score: 0.8852 - lr: 1.0000e-04
# Epoch 48/100
# 17/17 [==============================] - 37s 2s/step - loss: 0.1909 - iou_score: 0.7360 - f1-score: 0.8234 - val_loss: 0.1444 - val_iou_score: 0.7925 - val_f1-score: 0.8696 - lr: 1.0000e-04
# Epoch 49/100
# 17/17 [==============================] - 55s 3s/step - loss: 0.1972 - iou_score: 0.7282 - f1-score: 0.8170 - val_loss: 0.1262 - val_iou_score: 0.8144 - val_f1-score: 0.8865 - lr: 1.0000e-04
# Epoch 50/100
# 17/17 [==============================] - 37s 2s/step - loss: 0.1801 - iou_score: 0.7428 - f1-score: 0.8330 - val_loss: 0.1270 - val_iou_score: 0.8131 - val_f1-score: 0.8855 - lr: 1.0000e-04
# Epoch 51/100
# 17/17 [==============================] - 42s 2s/step - loss: 0.2040 - iou_score: 0.7166 - f1-score: 0.8097 - val_loss: 0.1328 - val_iou_score: 0.8054 - val_f1-score: 0.8794 - lr: 1.0000e-04
# Epoch 52/100
# 17/17 [==============================] - 42s 2s/step - loss: 0.2342 - iou_score: 0.6889 - f1-score: 0.7796 - val_loss: 0.1309 - val_iou_score: 0.8073 - val_f1-score: 0.8810 - lr: 1.0000e-04
# Epoch 53/100
# 17/17 [==============================] - 42s 2s/step - loss: 0.2068 - iou_score: 0.7135 - f1-score: 0.8063 - val_loss: 0.1281 - val_iou_score: 0.8107 - val_f1-score: 0.8836 - lr: 1.0000e-04
# Epoch 54/100
# 17/17 [==============================] - 42s 2s/step - loss: 0.1964 - iou_score: 0.7224 - f1-score: 0.8164 - val_loss: 0.1285 - val_iou_score: 0.8097 - val_f1-score: 0.8827 - lr: 1.0000e-04
# Epoch 55/100
# 17/17 [==============================] - 42s 3s/step - loss: 0.2136 - iou_score: 0.7053 - f1-score: 0.7996 - val_loss: 0.1264 - val_iou_score: 0.8120 - val_f1-score: 0.8847 - lr: 1.0000e-04
# Epoch 56/100
# 17/17 [==============================] - 42s 2s/step - loss: 0.1763 - iou_score: 0.7464 - f1-score: 0.8359 - val_loss: 0.1287 - val_iou_score: 0.8089 - val_f1-score: 0.8824 - lr: 1.0000e-04
# Epoch 57/100
# 17/17 [==============================] - 42s 2s/step - loss: 0.2140 - iou_score: 0.7071 - f1-score: 0.7985 - val_loss: 0.1276 - val_iou_score: 0.8095 - val_f1-score: 0.8828 - lr: 1.0000e-04
# Epoch 58/100
# 17/17 [==============================] - 41s 3s/step - loss: 0.1824 - iou_score: 0.7390 - f1-score: 0.8291 - val_loss: 0.1265 - val_iou_score: 0.8117 - val_f1-score: 0.8845 - lr: 1.0000e-04
# Epoch 59/100
# 17/17 [==============================] - 42s 3s/step - loss: 0.2141 - iou_score: 0.7096 - f1-score: 0.7980 - val_loss: 0.1276 - val_iou_score: 0.8094 - val_f1-score: 0.8828 - lr: 1.0000e-04
# Epoch 60/100
# 17/17 [==============================] - 36s 2s/step - loss: 0.1814 - iou_score: 0.7361 - f1-score: 0.8297 - val_loss: 0.1273 - val_iou_score: 0.8097 - val_f1-score: 0.8830 - lr: 1.0000e-05
# Epoch 61/100
# 17/17 [==============================] - 42s 3s/step - loss: 0.2006 - iou_score: 0.7221 - f1-score: 0.8111 - val_loss: 0.1283 - val_iou_score: 0.8083 - val_f1-score: 0.8818 - lr: 1.0000e-05
# Epoch 62/100
# 17/17 [==============================] - 42s 3s/step - loss: 0.2230 - iou_score: 0.6941 - f1-score: 0.7890 - val_loss: 0.1286 - val_iou_score: 0.8079 - val_f1-score: 0.8815 - lr: 1.0000e-05
# Epoch 63/100
# 17/17 [==============================] - 41s 3s/step - loss: 0.1816 - iou_score: 0.7392 - f1-score: 0.8295 - val_loss: 0.1289 - val_iou_score: 0.8072 - val_f1-score: 0.8810 - lr: 1.0000e-05
# Epoch 64/100
# 17/17 [==============================] - 32s 2s/step - loss: 0.1762 - iou_score: 0.7444 - f1-score: 0.8352 - val_loss: 0.1278 - val_iou_score: 0.8087 - val_f1-score: 0.8822 - lr: 1.0000e-05
# Epoch 65/100
# 17/17 [==============================] - 42s 3s/step - loss: 0.1798 - iou_score: 0.7391 - f1-score: 0.8316 - val_loss: 0.1269 - val_iou_score: 0.8099 - val_f1-score: 0.8831 - lr: 1.0000e-05
# Epoch 66/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.2015 - iou_score: 0.7235 - f1-score: 0.8102 - val_loss: 0.1270 - val_iou_score: 0.8097 - val_f1-score: 0.8829 - lr: 1.0000e-05
# Epoch 67/100
# 17/17 [==============================] - 32s 2s/step - loss: 0.1706 - iou_score: 0.7520 - f1-score: 0.8405 - val_loss: 0.1275 - val_iou_score: 0.8090 - val_f1-score: 0.8825 - lr: 1.0000e-05
# Epoch 68/100
# 17/17 [==============================] - 42s 3s/step - loss: 0.1902 - iou_score: 0.7328 - f1-score: 0.8212 - val_loss: 0.1277 - val_iou_score: 0.8087 - val_f1-score: 0.8822 - lr: 1.0000e-05
# Epoch 69/100
# 17/17 [==============================] - 42s 2s/step - loss: 0.2150 - iou_score: 0.7065 - f1-score: 0.7970 - val_loss: 0.1272 - val_iou_score: 0.8096 - val_f1-score: 0.8828 - lr: 1.0000e-05
# Epoch 70/100
# 17/17 [==============================] - 47s 3s/step - loss: 0.2077 - iou_score: 0.7158 - f1-score: 0.8038 - val_loss: 0.1271 - val_iou_score: 0.8097 - val_f1-score: 0.8829 - lr: 1.0000e-06
# Epoch 71/100
# 17/17 [==============================] - 42s 3s/step - loss: 0.1747 - iou_score: 0.7487 - f1-score: 0.8367 - val_loss: 0.1272 - val_iou_score: 0.8096 - val_f1-score: 0.8828 - lr: 1.0000e-06
# Epoch 72/100
# 17/17 [==============================] - 42s 3s/step - loss: 0.2080 - iou_score: 0.7137 - f1-score: 0.8040 - val_loss: 0.1270 - val_iou_score: 0.8098 - val_f1-score: 0.8829 - lr: 1.0000e-06
# Epoch 73/100
# 17/17 [==============================] - 42s 3s/step - loss: 0.1920 - iou_score: 0.7334 - f1-score: 0.8192 - val_loss: 0.1270 - val_iou_score: 0.8098 - val_f1-score: 0.8830 - lr: 1.0000e-06
# Epoch 74/100
# 17/17 [==============================] - 47s 3s/step - loss: 0.2272 - iou_score: 0.6983 - f1-score: 0.7849 - val_loss: 0.1268 - val_iou_score: 0.8097 - val_f1-score: 0.8829 - lr: 1.0000e-06
# Epoch 75/100
# 17/17 [==============================] - 42s 3s/step - loss: 0.1976 - iou_score: 0.7210 - f1-score: 0.8138 - val_loss: 0.1268 - val_iou_score: 0.8099 - val_f1-score: 0.8831 - lr: 1.0000e-06
# Epoch 76/100
# 17/17 [==============================] - 42s 3s/step - loss: 0.1723 - iou_score: 0.7555 - f1-score: 0.8387 - val_loss: 0.1268 - val_iou_score: 0.8100 - val_f1-score: 0.8831 - lr: 1.0000e-06
# Epoch 77/100
# 17/17 [==============================] - 42s 3s/step - loss: 0.2024 - iou_score: 0.7242 - f1-score: 0.8096 - val_loss: 0.1268 - val_iou_score: 0.8099 - val_f1-score: 0.8830 - lr: 1.0000e-06
# Epoch 78/100
# 17/17 [==============================] - 42s 3s/step - loss: 0.1878 - iou_score: 0.7349 - f1-score: 0.8236 - val_loss: 0.1267 - val_iou_score: 0.8099 - val_f1-score: 0.8831 - lr: 1.0000e-06
# Epoch 79/100
# 17/17 [==============================] - 42s 2s/step - loss: 0.1635 - iou_score: 0.7594 - f1-score: 0.8475 - val_loss: 0.1268 - val_iou_score: 0.8099 - val_f1-score: 0.8831 - lr: 1.0000e-06
# Epoch 80/100
# 17/17 [==============================] - 42s 2s/step - loss: 0.2347 - iou_score: 0.6852 - f1-score: 0.7776 - val_loss: 0.1267 - val_iou_score: 0.8100 - val_f1-score: 0.8831 - lr: 1.0000e-07
# Epoch 81/100
# 17/17 [==============================] - 47s 3s/step - loss: 0.1804 - iou_score: 0.7435 - f1-score: 0.8309 - val_loss: 0.1268 - val_iou_score: 0.8098 - val_f1-score: 0.8830 - lr: 1.0000e-07
# Epoch 82/100
# 17/17 [==============================] - 42s 3s/step - loss: 0.2040 - iou_score: 0.7173 - f1-score: 0.8080 - val_loss: 0.1268 - val_iou_score: 0.8099 - val_f1-score: 0.8830 - lr: 1.0000e-07
# Epoch 83/100
# 17/17 [==============================] - 42s 3s/step - loss: 0.1785 - iou_score: 0.7453 - f1-score: 0.8329 - val_loss: 0.1270 - val_iou_score: 0.8096 - val_f1-score: 0.8828 - lr: 1.0000e-07
# Epoch 84/100
# 17/17 [==============================] - 42s 3s/step - loss: 0.1820 - iou_score: 0.7414 - f1-score: 0.8293 - val_loss: 0.1269 - val_iou_score: 0.8097 - val_f1-score: 0.8829 - lr: 1.0000e-07
# Epoch 85/100
# 17/17 [==============================] - 42s 2s/step - loss: 0.1632 - iou_score: 0.7638 - f1-score: 0.8479 - val_loss: 0.1271 - val_iou_score: 0.8096 - val_f1-score: 0.8828 - lr: 1.0000e-07
# Epoch 86/100
# 17/17 [==============================] - 42s 2s/step - loss: 0.2003 - iou_score: 0.7254 - f1-score: 0.8110 - val_loss: 0.1270 - val_iou_score: 0.8097 - val_f1-score: 0.8829 - lr: 1.0000e-07
# Epoch 87/100
# 17/17 [==============================] - 47s 3s/step - loss: 0.2018 - iou_score: 0.7184 - f1-score: 0.8102 - val_loss: 0.1268 - val_iou_score: 0.8099 - val_f1-score: 0.8830 - lr: 1.0000e-07
# Epoch 88/100
# 17/17 [==============================] - 42s 3s/step - loss: 0.1734 - iou_score: 0.7529 - f1-score: 0.8378 - val_loss: 0.1269 - val_iou_score: 0.8097 - val_f1-score: 0.8829 - lr: 1.0000e-07
# Epoch 89/100
# 17/17 [==============================] - 42s 3s/step - loss: 0.1945 - iou_score: 0.7257 - f1-score: 0.8169 - val_loss: 0.1268 - val_iou_score: 0.8097 - val_f1-score: 0.8829 - lr: 1.0000e-07
# Epoch 90/100
# 17/17 [==============================] - 42s 3s/step - loss: 0.2010 - iou_score: 0.7193 - f1-score: 0.8106 - val_loss: 0.1267 - val_iou_score: 0.8099 - val_f1-score: 0.8831 - lr: 1.0000e-08
# Epoch 91/100
# 17/17 [==============================] - 42s 3s/step - loss: 0.1871 - iou_score: 0.7363 - f1-score: 0.8242 - val_loss: 0.1267 - val_iou_score: 0.8099 - val_f1-score: 0.8830 - lr: 1.0000e-08
# Epoch 92/100
# 17/17 [==============================] - 42s 3s/step - loss: 0.2019 - iou_score: 0.7208 - f1-score: 0.8099 - val_loss: 0.1267 - val_iou_score: 0.8098 - val_f1-score: 0.8830 - lr: 1.0000e-08
# Epoch 93/100
# 17/17 [==============================] - 42s 3s/step - loss: 0.1904 - iou_score: 0.7312 - f1-score: 0.8208 - val_loss: 0.1267 - val_iou_score: 0.8099 - val_f1-score: 0.8830 - lr: 1.0000e-08
# Epoch 94/100
# 17/17 [==============================] - 47s 3s/step - loss: 0.2061 - iou_score: 0.7195 - f1-score: 0.8056 - val_loss: 0.1267 - val_iou_score: 0.8099 - val_f1-score: 0.8831 - lr: 1.0000e-08
# Epoch 95/100
# 17/17 [==============================] - 42s 3s/step - loss: 0.1723 - iou_score: 0.7556 - f1-score: 0.8388 - val_loss: 0.1266 - val_iou_score: 0.8100 - val_f1-score: 0.8832 - lr: 1.0000e-08
# Epoch 96/100
# 17/17 [==============================] - 42s 3s/step - loss: 0.2081 - iou_score: 0.7175 - f1-score: 0.8036 - val_loss: 0.1265 - val_iou_score: 0.8105 - val_f1-score: 0.8835 - lr: 1.0000e-08
# Epoch 97/100
# 17/17 [==============================] - 42s 3s/step - loss: 0.1740 - iou_score: 0.7499 - f1-score: 0.8372 - val_loss: 0.1265 - val_iou_score: 0.8104 - val_f1-score: 0.8835 - lr: 1.0000e-08
# Epoch 98/100
# 17/17 [==============================] - 42s 3s/step - loss: 0.2058 - iou_score: 0.7152 - f1-score: 0.8058 - val_loss: 0.1263 - val_iou_score: 0.8106 - val_f1-score: 0.8836 - lr: 1.0000e-08
# Epoch 99/100
# 17/17 [==============================] - 42s 2s/step - loss: 0.2204 - iou_score: 0.7075 - f1-score: 0.7914 - val_loss: 0.1265 - val_iou_score: 0.8102 - val_f1-score: 0.8832 - lr: 1.0000e-08
# Epoch 100/100
# 17/17 [==============================] - 42s 2s/step - loss: 0.2109 - iou_score: 0.7079 - f1-score: 0.8009 - val_loss: 0.1266 - val_iou_score: 0.8100 - val_f1-score: 0.8831 - lr: 1.0000e-09

# %%
# Plot training & validation iou_score values
plt.figure(figsize=(30, 10))
plt.subplot(121)
plt.plot(history.history['iou_score'])
plt.plot(history.history['val_iou_score'])
plt.title('Model iou_score')
plt.ylabel('iou_score')
plt.xlabel('Epoch')
plt.legend(['Train', 'Valid'], loc='upper left')

# Plot training & validation loss values
plt.subplot(122)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Valid'], loc='upper left')
plt.show()

# %% [markdown]
# # Model Evaluation

# %%
test_dataset = Dataset(
    x_test_dir, 
    y_test_dir, 
    classes=CLASSES, 
    augmentation=get_validation_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
)

test_dataloader = Dataloder(test_dataset, batch_size=1, shuffle=False)

# %%
# load best weights
model.load_weights('sacrum_unet_effB7_1129.h5')

# %%
scores = model.evaluate_generator(test_dataloader)

print("Loss: {:.5}".format(scores[0]))
for metric, value in zip(metrics, scores[1:]):
    print("mean {}: {:.5}".format(metric.__name__, value))
# Out:
# Loss: 0.11119
# mean iou_score: 0.8335
# mean f1-score: 0.90052
# C:\Users\User\AppData\Local\Temp\ipykernel_32552\3518042878.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   scores = model.evaluate_generator(test_dataloader)

# %% [markdown]
# # Visualization of results on test dataset

# %%
# Define a function to convert mask to color
def mask_to_color(mask, num_classes=2):
    """
    Convert a mask with shape (H, W, num_classes) to a color image.
    """
    colors = np.array([
        [0, 0, 0],  # background
        [255, 255, 255],  # bone
    ])
    mask = np.argmax(mask, axis=-1)
    color_mask = np.zeros((mask.shape[0], mask.shape[1], 3), dtype=np.uint8)
    for c in range(num_classes):
        color_mask[mask == c] = colors[c]
    return color_mask

# helper function for data visualization
def visualize(**images):
    """PLot images in one row."""
    n = len(images)
    plt.figure(figsize=(16, 5))
    for i, (name, image) in enumerate(images.items()):
        plt.subplot(1, n, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.title(' '.join(name.split('_')).title())
        if name == 'image':
            plt.imshow(image, cmap='gray')
        else:
            plt.imshow(mask_to_color(image))
    plt.show()

# %%
n = 2
ids = np.random.choice(np.arange(len(test_dataset)), size=n)

for i in ids:
    
    image, gt_mask = test_dataset[i]
    image = np.expand_dims(image, axis=0)
    pr_mask = model.predict(image)
    
    visualize(
        image=denormalize(image.squeeze()),
        gt_mask=gt_mask.squeeze(),
        pr_mask=pr_mask.squeeze(),
    )
# Out:
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 57ms/step

# %%
import keras.backend as K

# 每次訓練後清理 Keras 會話
def clear_keras_session():
    K.clear_session()
    
clear_keras_session()
